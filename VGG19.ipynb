# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import tensorflow as tf

from sklearn.metrics import confusion_matrix, classification_report

# %%
image_dir = Path(r"C:\Users\net pc\Desktop\Training Datsets")

# %%
filepaths = list(image_dir.glob(r'*/*.JPG'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

image_df = pd.concat([filepaths, labels], axis=1)

# %%
image_df
# Out:
#                                                Filepath             Label
# 0     C:\Users\net pc\Desktop\Training Datsets\gliom...     glioma_tumors
# 1     C:\Users\net pc\Desktop\Training Datsets\gliom...     glioma_tumors
# 2     C:\Users\net pc\Desktop\Training Datsets\gliom...     glioma_tumors
# 3     C:\Users\net pc\Desktop\Training Datsets\gliom...     glioma_tumors
# 4     C:\Users\net pc\Desktop\Training Datsets\gliom...     glioma_tumors
# ...                                                 ...               ...
# 9995  C:\Users\net pc\Desktop\Training Datsets\pitui...  pituitary_tumors
# 9996  C:\Users\net pc\Desktop\Training Datsets\pitui...  pituitary_tumors
# 9997  C:\Users\net pc\Desktop\Training Datsets\pitui...  pituitary_tumors
# 9998  C:\Users\net pc\Desktop\Training Datsets\pitui...  pituitary_tumors
# 9999  C:\Users\net pc\Desktop\Training Datsets\pitui...  pituitary_tumors
#
# [10000 rows x 2 columns]

# %%
train_df, test_df = train_test_split(image_df, train_size=0.80, shuffle=True, random_state=1)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255,
                                                                  horizontal_flip=True,
                                                                  width_shift_range=0.2,
                                                                  height_shift_range=0.2,
                                                                  validation_split=0.2)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# %%
train_images = train_generator.flow_from_dataframe(dataframe=train_df,
                                                   x_col='Filepath',
                                                   y_col='Label',
                                                   target_size=(64, 64),
                                                   color_mode='rgb',
                                                   class_mode='categorical',
                                                   batch_size=32,
                                                   shuffle=True,
                                                   seed=42,
                                                   subset='training')

val_images = train_generator.flow_from_dataframe(dataframe=train_df,
                                                 x_col='Filepath',
                                                 y_col='Label',
                                                 target_size=(64, 64),
                                                 color_mode='rgb',
                                                 class_mode='categorical',
                                                 batch_size=32,
                                                 shuffle=True,
                                                 seed=42,
                                                 subset='validation')

test_images = test_generator.flow_from_dataframe(dataframe=test_df,
                                                 x_col='Filepath',
                                                 y_col='Label',
                                                 target_size=(64, 64),
                                                 color_mode='rgb',
                                                 class_mode='categorical',
                                                 batch_size=32,
                                                 shuffle=False)
# Out:
# Found 6400 validated image filenames belonging to 4 classes.
# Found 1600 validated image filenames belonging to 4 classes.
# Found 2000 validated image filenames belonging to 4 classes.

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv3D, MaxPool3D , Dropout, Flatten
from tensorflow.keras.layers import Dropout

from keras.applications.vgg19 import VGG19
#from keras.applications.vgg16 import preprocess_input


vgg = VGG19(input_shape= (64, 64, 3), weights='imagenet', include_top=False)
vgg.trainable = False

# %%
model = keras.Sequential([
    vgg,
    keras.layers.Flatten(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(units=32, activation='relu'),
    keras.layers.Dropout(0.25),
    keras.layers.Dense(units=4, activation='softmax'),
])

# %%
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ vgg19 (Functional)                   │ ?                           │      20,024,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 20,024,384 (76.39 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %%
for layer in model.layers:
    print(layer, layer.trainable)
# Out:
# <Functional name=vgg19, built=True> False
# <Flatten name=flatten, built=False> True
# <Dropout name=dropout, built=True> True
# <Dense name=dense, built=False> True
# <Dropout name=dropout_1, built=True> True
# <Dense name=dense_1, built=False> True

# %%
history = model.fit(
    train_images,
    validation_data=val_images,
    epochs=50,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=5,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            patience=3
        )
    ]
)
# Out:
# Epoch 1/50
# C:\Users\Public\Efendim\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 154ms/step - accuracy: 0.3347 - loss: 1.4135 - val_accuracy: 0.5331 - val_loss: 1.1239 - learning_rate: 0.0010
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 31s 154ms/step - accuracy: 0.4689 - loss: 1.1890 - val_accuracy: 0.6288 - val_loss: 0.9750 - learning_rate: 0.0010
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 31s 153ms/step - accuracy: 0.5460 - loss: 1.0694 - val_accuracy: 0.6513 - val_loss: 0.9174 - learning_rate: 0.0010
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 31s 153ms/step - accuracy: 0.5628 - loss: 1.0267 - val_accuracy: 0.6800 - val_loss: 0.8591 - learning_rate: 0.0010
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 31s 155ms/step - accuracy: 0.5802 - loss: 0.9817 - val_accuracy: 0.6994 - val_loss: 0.8130 - learning_rate: 0.0010
# Epoch 6/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 157ms/step - accuracy: 0.6001 - loss: 0.9598 - val_accuracy: 0.6888 - val_loss: 0.8054 - learning_rate: 0.0010
# Epoch 7/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 157ms/step - accuracy: 0.6075 - loss: 0.9353 - val_accuracy: 0.6925 - val_loss: 0.7795 - learning_rate: 0.0010
# Epoch 8/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 158ms/step - accuracy: 0.6234 - loss: 0.9218 - val_accuracy: 0.7244 - val_loss: 0.7679 - learning_rate: 0.0010
# Epoch 9/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 160ms/step - accuracy: 0.6206 - loss: 0.9084 - val_accuracy: 0.7250 - val_loss: 0.7407 - learning_rate: 0.0010
# Epoch 10/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 158ms/step - accuracy: 0.6300 - loss: 0.8849 - val_accuracy: 0.7212 - val_loss: 0.7465 - learning_rate: 0.0010
# Epoch 11/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 158ms/step - accuracy: 0.6365 - loss: 0.8772 - val_accuracy: 0.7513 - val_loss: 0.7132 - learning_rate: 0.0010
# Epoch 12/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 157ms/step - accuracy: 0.6345 - loss: 0.8752 - val_accuracy: 0.7456 - val_loss: 0.7231 - learning_rate: 0.0010
# Epoch 13/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 159ms/step - accuracy: 0.6297 - loss: 0.8796 - val_accuracy: 0.7525 - val_loss: 0.6770 - learning_rate: 0.0010
# Epoch 14/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 158ms/step - accuracy: 0.6589 - loss: 0.8319 - val_accuracy: 0.7406 - val_loss: 0.6993 - learning_rate: 0.0010
# Epoch 15/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 158ms/step - accuracy: 0.6407 - loss: 0.8483 - val_accuracy: 0.7369 - val_loss: 0.6936 - learning_rate: 0.0010
# Epoch 16/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 159ms/step - accuracy: 0.6591 - loss: 0.8323 - val_accuracy: 0.7444 - val_loss: 0.6728 - learning_rate: 0.0010
# Epoch 17/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 157ms/step - accuracy: 0.6544 - loss: 0.8343 - val_accuracy: 0.7456 - val_loss: 0.6574 - learning_rate: 0.0010
# Epoch 18/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 158ms/step - accuracy: 0.6475 - loss: 0.8384 - val_accuracy: 0.7556 - val_loss: 0.6603 - learning_rate: 0.0010
# Epoch 19/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 158ms/step - accuracy: 0.6561 - loss: 0.8240 - val_accuracy: 0.7656 - val_loss: 0.6454 - learning_rate: 0.0010
# Epoch 20/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 160ms/step - accuracy: 0.6681 - loss: 0.8235 - val_accuracy: 0.7625 - val_loss: 0.6496 - learning_rate: 0.0010
# Epoch 21/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 31s 155ms/step - accuracy: 0.6657 - loss: 0.8085 - val_accuracy: 0.7563 - val_loss: 0.6433 - learning_rate: 0.0010
# Epoch 22/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 157ms/step - accuracy: 0.6582 - loss: 0.8322 - val_accuracy: 0.7731 - val_loss: 0.6326 - learning_rate: 0.0010
# Epoch 23/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 159ms/step - accuracy: 0.6793 - loss: 0.8026 - val_accuracy: 0.7713 - val_loss: 0.6036 - learning_rate: 0.0010
# Epoch 24/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 159ms/step - accuracy: 0.6645 - loss: 0.8095 - val_accuracy: 0.7638 - val_loss: 0.6345 - learning_rate: 0.0010
# Epoch 25/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 31s 155ms/step - accuracy: 0.6645 - loss: 0.8073 - val_accuracy: 0.7694 - val_loss: 0.6152 - learning_rate: 0.0010
# Epoch 26/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 156ms/step - accuracy: 0.6686 - loss: 0.8050 - val_accuracy: 0.7700 - val_loss: 0.6256 - learning_rate: 0.0010
# Epoch 27/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 156ms/step - accuracy: 0.6887 - loss: 0.7650 - val_accuracy: 0.7812 - val_loss: 0.6051 - learning_rate: 1.0000e-04
# Epoch 28/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 160ms/step - accuracy: 0.6759 - loss: 0.7771 - val_accuracy: 0.7894 - val_loss: 0.5923 - learning_rate: 1.0000e-04
# Epoch 29/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 157ms/step - accuracy: 0.6815 - loss: 0.7641 - val_accuracy: 0.7912 - val_loss: 0.5787 - learning_rate: 1.0000e-04
# Epoch 30/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 157ms/step - accuracy: 0.6768 - loss: 0.7948 - val_accuracy: 0.7794 - val_loss: 0.5982 - learning_rate: 1.0000e-04
# Epoch 31/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 159ms/step - accuracy: 0.6851 - loss: 0.7891 - val_accuracy: 0.7894 - val_loss: 0.5932 - learning_rate: 1.0000e-04
# Epoch 32/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 158ms/step - accuracy: 0.6848 - loss: 0.7666 - val_accuracy: 0.7744 - val_loss: 0.6058 - learning_rate: 1.0000e-04
# Epoch 33/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 156ms/step - accuracy: 0.6884 - loss: 0.7514 - val_accuracy: 0.7800 - val_loss: 0.6052 - learning_rate: 1.0000e-05
# Epoch 34/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 158ms/step - accuracy: 0.6933 - loss: 0.7657 - val_accuracy: 0.7725 - val_loss: 0.6230 - learning_rate: 1.0000e-05

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Custom Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Accuracy', 'Validation Accuracy', 'loss', 'Validation Loss'])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Custom Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Loss', 'Validation Loss'], loc='upper right')
plt.show()

# %%
results = model.evaluate(test_images, verbose=0)

print("    Test Loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
#     Test Loss: 0.56629
# Test Accuracy: 78.65%

# %%
# Convert labels to one-hot encoding
from keras.utils import to_categorical

test_labels_onehot = to_categorical(test_images.labels, num_classes=4)

# Predict classes
predictions = model.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Create confusion matrix
cm = confusion_matrix(np.argmax(test_labels_onehot, axis=1), predicted_classes)

# Create classification report
clr = classification_report(np.argmax(test_labels_onehot, axis=1), predicted_classes, target_names=["glioma_tumors", "meningioma_tumors", "pituitary_tumors", "no_tumors"])

# Plot confusion matrix
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Blues', cbar=False)
plt.xticks(ticks=np.arange(4) + 0.5, labels=["glioma_tumors", "meningioma_tumors", "pituitary_tumors", "no_tumors"], rotation=45)
plt.yticks(ticks=np.arange(4) + 0.5, labels=["glioma_tumors", "meningioma_tumors", "pituitary_tumors", "no_tumors"], rotation=0)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix of the C-VGG19 Model")
plt.show()

# Print classification report
print("Classification Report:\n----------------------\n", clr)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 117ms/step
# Classification Report:
# ----------------------
#                     precision    recall  f1-score   support
#
#     glioma_tumors       0.70      0.70      0.70       528
# meningioma_tumors       0.85      0.69      0.76       493
#  pituitary_tumors       0.76      0.86      0.81       491
#         no_tumors       0.86      0.91      0.88       488
#
#          accuracy                           0.79      2000
#         macro avg       0.79      0.79      0.79      2000
#      weighted avg       0.79      0.79      0.78      2000

# %%
# Obtain predicted probabilities
predicted_probabilities = model.predict(test_images)

# Import necessary libraries
from sklearn.metrics import roc_auc_score, roc_curve

# Convert labels to one-hot encoding
from keras.utils import to_categorical
test_labels_onehot = to_categorical(test_images.labels, num_classes=4)

# Compute AUC ROC for each class
auc_roc = dict()
for i in range(4):
    auc_roc[i] = roc_auc_score(test_labels_onehot[:, i], predicted_probabilities[:, i])

# Plot ROC curve for each class
plt.figure(figsize=(8, 6))
for i in range(4):
    fpr, tpr, _ = roc_curve(test_labels_onehot[:, i], predicted_probabilities[:, i])
    plt.plot(fpr, tpr, label='ROC curve for {} (area = {:.2f})'.format(["glioma_tumors", "meningioma_tumors", "pituitary_tumors", "no_tumors"][i], auc_roc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Print AUC ROC for each class
for i in range(4):
    print("AUC ROC for {}: {:.5f}".format(["glioma_tumors", "meningioma_tumors", "pituitary_tumors", "no_tumors"][i], auc_roc[i]))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step
# AUC ROC for glioma_tumors: 0.89655
# AUC ROC for meningioma_tumors: 0.93795
# AUC ROC for pituitary_tumors: 0.95837
# AUC ROC for no_tumors: 0.98540

# %%
# save the model to a file
#model.save('VGG19- ACC vs Kidney tumor .h5')
