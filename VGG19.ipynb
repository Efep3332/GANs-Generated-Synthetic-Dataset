# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import tensorflow as tf

from sklearn.metrics import confusion_matrix, classification_report
# Out:
# WARNING:tensorflow:From C:\Users\Public\Efendim\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
image_dir = Path(r"C:\Users\net pc\Desktop\THESIS PROJECT\AUGMENTED\DATA")

# %%
filepaths = list(image_dir.glob(r'*/*.JPG'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

image_df = pd.concat([filepaths, labels], axis=1)

# %%
image_df
# Out:
#                                                 Filepath  \
# 0      C:\Users\net pc\Desktop\THESIS PROJECT\AUGMENT...
# 1      C:\Users\net pc\Desktop\THESIS PROJECT\AUGMENT...
# 2      C:\Users\net pc\Desktop\THESIS PROJECT\AUGMENT...
# 3      C:\Users\net pc\Desktop\THESIS PROJECT\AUGMENT...
# 4      C:\Users\net pc\Desktop\THESIS PROJECT\AUGMENT...
# ...                                                  ...
# 39995  C:\Users\net pc\Desktop\THESIS PROJECT\AUGMENT...
# 39996  C:\Users\net pc\Desktop\THESIS PROJECT\AUGMENT...
# 39997  C:\Users\net pc\Desktop\THESIS PROJECT\AUGMENT...
# 39998  C:\Users\net pc\Desktop\THESIS PROJECT\AUGMENT...
# 39999  C:\Users\net pc\Desktop\THESIS PROJECT\AUGMENT...
#
#                         Label
# 0       brain_tumor_augmented
# 1       brain_tumor_augmented
# 2       brain_tumor_augmented
# 3       brain_tumor_augmented
# 4       brain_tumor_augmented
# ...                       ...
# 39995  kidney_tumor_augmented
# 39996  kidney_tumor_augmented
# 39997  kidney_tumor_augmented
# 39998  kidney_tumor_augmented
# 39999  kidney_tumor_augmented
#
# [40000 rows x 2 columns]

# %%
train_df, test_df = train_test_split(image_df, train_size=0.80, shuffle=True, random_state=1)

# %%
from keras.preprocessing.image import ImageDataGenerator

train_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255,
                                                                  horizontal_flip=True,
                                                                  width_shift_range=0.2,
                                                                  height_shift_range=0.2,
                                                                  validation_split=0.2)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# %%
train_images = train_generator.flow_from_dataframe(dataframe=train_df,
                                                   x_col='Filepath',
                                                   y_col='Label',
                                                   target_size=(64, 64),
                                                   color_mode='rgb',
                                                   class_mode='binary',
                                                   batch_size=32,
                                                   shuffle=True,
                                                   seed=42,
                                                   subset='training')

val_images = train_generator.flow_from_dataframe(dataframe=train_df,
                                                 x_col='Filepath',
                                                 y_col='Label',
                                                 target_size=(64, 64),
                                                 color_mode='rgb',
                                                 class_mode='binary',
                                                 batch_size=32,
                                                 shuffle=True,
                                                 seed=42,
                                                 subset='validation')

test_images = test_generator.flow_from_dataframe(dataframe=test_df,
                                                 x_col='Filepath',
                                                 y_col='Label',
                                                 target_size=(64, 64),
                                                 color_mode='rgb',
                                                 class_mode='binary',
                                                 batch_size=32,
                                                 shuffle=False)
# Out:
# Found 25600 validated image filenames belonging to 2 classes.
# Found 6400 validated image filenames belonging to 2 classes.
# Found 8000 validated image filenames belonging to 2 classes.

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv3D, MaxPool3D , Dropout, Flatten
from tensorflow.keras.layers import Dropout

from keras.applications.vgg19 import VGG19
#from keras.applications.vgg16 import preprocess_input


vgg = VGG19(input_shape= (64, 64, 3), weights='imagenet', include_top=False)
vgg.trainable = False
# Out:
# WARNING:tensorflow:From C:\Users\Public\Efendim\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Public\Efendim\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model = keras.Sequential([
    vgg,
    keras.layers.Flatten(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(units=32, activation='relu'),
    keras.layers.Dropout(0.25),
    keras.layers.Dense(units=1, activation='sigmoid'),
])

# %%
model.compile(
  loss='binary_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:From C:\Users\Public\Efendim\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 2, 2, 512)         20024384
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 32)                65568
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 20089985 (76.64 MB)
# Trainable params: 65601 (256.25 KB)
# Non-trainable params: 20024384 (76.39 MB)
# _________________________________________________________________

# %%
for layer in model.layers:
    print(layer, layer.trainable)
# Out:
# <keras.src.engine.functional.Functional object at 0x000002ADD30BA510> False
# <keras.src.layers.reshaping.flatten.Flatten object at 0x000002ADD3481A10> True
# <keras.src.layers.regularization.dropout.Dropout object at 0x000002ADD3113510> True
# <keras.src.layers.core.dense.Dense object at 0x000002ADD338A450> True
# <keras.src.layers.regularization.dropout.Dropout object at 0x000002ADD311A2D0> True
# <keras.src.layers.core.dense.Dense object at 0x000002ADD32EBE50> True

# %%
history = model.fit(
    train_images,
    validation_data=val_images,
    epochs=50,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=5,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            patience=3
        )
    ]
)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\Public\Efendim\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Public\Efendim\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 800/800 [==============================] - 289s 357ms/step - loss: 0.0983 - accuracy: 0.9632 - val_loss: 0.0261 - val_accuracy: 0.9919 - lr: 0.0010
# Epoch 2/50
# 800/800 [==============================] - 303s 379ms/step - loss: 0.0516 - accuracy: 0.9818 - val_loss: 0.0253 - val_accuracy: 0.9903 - lr: 0.0010
# Epoch 3/50
# 800/800 [==============================] - 306s 382ms/step - loss: 0.0453 - accuracy: 0.9841 - val_loss: 0.0171 - val_accuracy: 0.9948 - lr: 0.0010
# Epoch 4/50
# 800/800 [==============================] - 304s 380ms/step - loss: 0.0440 - accuracy: 0.9848 - val_loss: 0.0183 - val_accuracy: 0.9941 - lr: 0.0010
# Epoch 5/50
# 800/800 [==============================] - 303s 379ms/step - loss: 0.0393 - accuracy: 0.9861 - val_loss: 0.0130 - val_accuracy: 0.9959 - lr: 0.0010
# Epoch 6/50
# 800/800 [==============================] - 309s 386ms/step - loss: 0.0366 - accuracy: 0.9875 - val_loss: 0.0140 - val_accuracy: 0.9955 - lr: 0.0010
# Epoch 7/50
# 800/800 [==============================] - 306s 383ms/step - loss: 0.0351 - accuracy: 0.9877 - val_loss: 0.0107 - val_accuracy: 0.9961 - lr: 0.0010
# Epoch 8/50
# 800/800 [==============================] - 304s 380ms/step - loss: 0.0308 - accuracy: 0.9887 - val_loss: 0.0068 - val_accuracy: 0.9981 - lr: 0.0010
# Epoch 9/50
# 800/800 [==============================] - 302s 378ms/step - loss: 0.0297 - accuracy: 0.9893 - val_loss: 0.0086 - val_accuracy: 0.9970 - lr: 0.0010
# Epoch 10/50
# 800/800 [==============================] - 304s 380ms/step - loss: 0.0286 - accuracy: 0.9898 - val_loss: 0.0069 - val_accuracy: 0.9978 - lr: 0.0010
# Epoch 11/50
# 800/800 [==============================] - 307s 383ms/step - loss: 0.0301 - accuracy: 0.9897 - val_loss: 0.0097 - val_accuracy: 0.9961 - lr: 0.0010
# Epoch 12/50
# 800/800 [==============================] - 303s 378ms/step - loss: 0.0246 - accuracy: 0.9923 - val_loss: 0.0065 - val_accuracy: 0.9983 - lr: 1.0000e-04
# Epoch 13/50
# 800/800 [==============================] - 306s 382ms/step - loss: 0.0245 - accuracy: 0.9918 - val_loss: 0.0057 - val_accuracy: 0.9986 - lr: 1.0000e-04
# Epoch 14/50
# 800/800 [==============================] - 305s 381ms/step - loss: 0.0201 - accuracy: 0.9930 - val_loss: 0.0062 - val_accuracy: 0.9980 - lr: 1.0000e-04
# Epoch 15/50
# 800/800 [==============================] - 300s 375ms/step - loss: 0.0237 - accuracy: 0.9916 - val_loss: 0.0062 - val_accuracy: 0.9981 - lr: 1.0000e-04
# Epoch 16/50
# 800/800 [==============================] - 306s 383ms/step - loss: 0.0224 - accuracy: 0.9918 - val_loss: 0.0063 - val_accuracy: 0.9977 - lr: 1.0000e-04
# Epoch 17/50
# 800/800 [==============================] - 306s 382ms/step - loss: 0.0215 - accuracy: 0.9926 - val_loss: 0.0067 - val_accuracy: 0.9980 - lr: 1.0000e-05
# Epoch 18/50
# 800/800 [==============================] - 307s 383ms/step - loss: 0.0219 - accuracy: 0.9930 - val_loss: 0.0058 - val_accuracy: 0.9984 - lr: 1.0000e-05

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Custom Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Accuracy', 'Validation Accuracy', 'loss', 'Validation Loss'])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Custom Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Loss', 'Validation Loss'], loc='upper right')
plt.show()

# %%
results = model.evaluate(test_images, verbose=0)

print("    Test Loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
#     Test Loss: 0.00286
# Test Accuracy: 99.95%

# %%
predictions = (model.predict(test_images) >= 0.5).astype(int)

cm = confusion_matrix(test_images.labels, predictions, labels=[0, 1])
clr = classification_report(test_images.labels, predictions, labels=[0, 1], target_names=["Brain tumor", "Kidney tumor"])

plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Blues', cbar=False)
plt.xticks(ticks=[0.5, 1.5], labels=["Brain tumor", "Kidney tumor"])
plt.yticks(ticks=[0.5, 1.5], labels=["Brain tumor", "Kidney tumor"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix of VGG19 Model")
plt.show()

print("Classification Report:\n----------------------\n", clr)
# Out:
# 250/250 [==============================] - 77s 304ms/step
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#  Brain tumor       1.00      1.00      1.00      4033
# Kidney tumor       1.00      1.00      1.00      3967
#
#     accuracy                           1.00      8000
#    macro avg       1.00      1.00      1.00      8000
# weighted avg       1.00      1.00      1.00      8000

# %%
# Obtain predicted probabilities
from sklearn.metrics import roc_auc_score, roc_curve

predicted_probabilities = model.predict(test_images)

# Compute AUC ROC
auc_roc = roc_auc_score(test_images.labels, predicted_probabilities)

print("AUC ROC: {:.5f}".format(auc_roc))

# Plot ROC curve
fpr, tpr, thresholds = roc_curve(test_images.labels, predicted_probabilities)

plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = {:.2f})'.format(auc_roc))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# 250/250 [==============================] - 76s 304ms/step
# AUC ROC: 0.99998

# %%
# save the model to a file
model.save('VGG19- ACC vs Kidney tumor .h5')
# Out:
# C:\Users\Public\Efendim\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
